# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
auto=pd.read_csv('true_car_listings.csv')
print(auto.shape)
# Out:
# (852122, 8)

# %%
auto.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
auto.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852122 entries, 0 to 852121
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Price    852122 non-null  int64
#  1   Year     852122 non-null  int64
#  2   Mileage  852122 non-null  int64
#  3   City     852122 non-null  object
#  4   State    852122 non-null  object
#  5   Vin      852122 non-null  object
#  6   Make     852122 non-null  object
#  7   Model    852122 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 52.0+ MB

# %%
for col in auto.columns:
    print('{} : {}'.format(col,auto[col].unique()))
# Out:
# Price : [ 8995 10888 10999 ... 63215 72260 60240]
# Year : [2014 2013 2016 2012 2009 2015 2010 2011 2007 2006 2008 2004 2017 2005
#  2003 2002 1999 2001 2000 1998 2018 1997]
# Mileage : [ 35725  19606  48851 ... 109198 202691 392123]
# City : ['El Paso' 'Long Island City' 'Windsor' ... 'Winslow' 'Bergenfield'
#  'Belmont']
# State : [' TX' ' NY' ' CO' ' UT' ' FL' ' CT' ' ID' ' ND' ' CA' ' NJ' ' OH' ' VA'
#  ' IN' ' AZ' ' OR' ' KS' ' NE' ' MA' ' MD' ' GA' ' MN' ' HI' ' LA' ' NM'
#  ' IL' ' AL' ' PA' ' SC' ' NC' ' WA' ' WI' ' OK' ' KY' ' MS' ' MO' ' ME'
#  ' AR' ' MI' ' NV' ' TN' ' Fl' ' NH' ' DE' ' WV' ' Az' ' VT' ' SD' ' IA'
#  ' RI' ' ga' ' Oh' ' MT' ' DC' ' AK' ' Va' ' WY' ' Md' ' Ca' ' Ga']
# Vin : ['19VDE2E53EE000083' '19VDE1F52DE012636' '19VDE2E52DE000025' ...
#  'YV4A22PL4G1000868' 'YV4A22NLXH1006162' 'YV4BC0ZX1H1109845']
# Make : ['Acura' 'Alfa' 'AM' 'Aston' 'Audi' 'Bentley' 'BMW' 'Buick' 'Cadillac'
#  'Chevrolet' 'Chrysler' 'Dodge' 'Ferrari' 'FIAT' 'Fisker' 'Ford'
# ...

# %%
for col in auto.columns:
    auto[col].replace({'?':np.nan},inplace=True)

# %%
auto.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
auto.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
polo=pd.read_csv('tc20171021.csv',on_bad_lines='skip')

# %%
polo.head()
# Out:
#    Id  Price  Year  Mileage            City State                Vin   Make  \
# 0   1  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1   2  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2   3  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3   4  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4   5  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
#
#                Model
# 0  EncoreConvenience
# 1          EncoreFWD
# 2      EncoreLeather
# 3          EncoreFWD
# 4  EncoreConvenience

# %%
polo.isnull().sum()
# Out:
# Id         0
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
polo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216250 entries, 0 to 1216249
# Data columns (total 9 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   Id       1216250 non-null  int64
#  1   Price    1216250 non-null  int64
#  2   Year     1216250 non-null  int64
#  3   Mileage  1216250 non-null  int64
#  4   City     1216250 non-null  object
#  5   State    1216250 non-null  object
#  6   Vin      1216250 non-null  object
#  7   Make     1216250 non-null  object
#  8   Model    1216250 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 83.5+ MB

# %%
for col in polo.columns:
    print('{} : {}'.format(col,polo[col].unique()))
# Out:
# Id : [      1       2       3 ... 1233040 1233041 1233042]
# Price : [16472 15749 16998 ... 68755 72260 60240]
# Year : [2015 2016 2014 2017 2013 2006 2003 2007 2005 2012 2011 2004 2009 2008
#  2001 2010 2018 2002 2000 1999 1997 1998]
# Mileage : [ 18681  27592  13650 ... 175099 217804 202691]
# City : ['Jefferson City' 'Highland' 'Boone' ... 'Northfield' 'Huntington Valley'
#  'Winslow']
# State : [' MO' ' IN' ' NC' ' LA' ' NV' ' NY' ' CA' ' AR' ' FL' ' AZ' ' KY' ' TN'
#  ' MI' ' TX' ' PA' ' OK' ' NJ' ' MD' ' OH' ' GA' ' Va' ' Fl' ' CO' ' ND'
#  ' AL' ' IL' ' MA' ' WA' ' WI' ' MN' ' VA' ' KS' ' RI' ' OR' ' MS' ' NM'
#  ' SC' ' NE' ' IA' ' NH' ' UT' ' ME' ' CT' ' HI' ' ID' ' DE' ' MT' ' WV'
#  ' WY' ' SD' ' AK' ' VT' ' Ga' ' ga' ' Md' ' Ca' ' Oh' ' Az' ' DC']
# Vin : ['KL4CJBSBXFB267643' 'KL4CJASB5FB245057' 'KL4CJCSB0FB264921' ...
#  'YV4A22PL4J1212676' 'YV4A22PL3H1186162' 'YV4A22NLXH1006162']
# Make : ['Buick' 'Acura' 'Alfa' 'Aston' 'Audi' 'Bentley' 'BMW' 'Cadillac'
# ...

# %%
for col in polo.columns:
    polo[col].replace({'?':np.nan},inplace=True)

# %%
polo.head()
# Out:
#    Id  Price  Year  Mileage            City State                Vin   Make  \
# 0   1  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1   2  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2   3  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3   4  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4   5  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
#
#                Model
# 0  EncoreConvenience
# 1          EncoreFWD
# 2      EncoreLeather
# 3          EncoreFWD
# 4  EncoreConvenience

# %%
polo.drop('Id', inplace=True, axis=1)

# %%
polo.head()
# Out:
#    Price  Year  Mileage            City State                Vin   Make  \
# 0  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
#
#                Model
# 0  EncoreConvenience
# 1          EncoreFWD
# 2      EncoreLeather
# 3          EncoreFWD
# 4  EncoreConvenience

# %%
x = pd.merge(auto, polo,on='Vin',how='outer')

# %%
#x.head()
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1227910 entries, 0 to 1227909
# Data columns (total 15 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Price_x    852122 non-null   float64
#  1   Year_x     852122 non-null   float64
#  2   Mileage_x  852122 non-null   float64
#  3   City_x     852122 non-null   object
#  4   State_x    852122 non-null   object
#  5   Vin        1227910 non-null  object
#  6   Make_x     852122 non-null   object
#  7   Model_x    852122 non-null   object
#  8   Price_y    1216297 non-null  float64
#  9   Year_y     1216297 non-null  float64
#  10  Mileage_y  1216297 non-null  float64
#  11  City_y     1216297 non-null  object
#  12  State_y    1216297 non-null  object
#  13  Make_y     1216297 non-null  object
#  14  Model_y    1216297 non-null  object
# dtypes: float64(6), object(9)
# memory usage: 149.9+ MB

# %%
x.isnull().sum()
# Out:
# Price_x      375788
# Year_x       375788
# Mileage_x    375788
# City_x       375788
# State_x      375788
# Vin               0
# Make_x       375788
# Model_x      375788
# Price_y       11613
# Year_y        11613
# Mileage_y     11613
# City_y        11613
# State_y       11613
# Make_y        11613
# Model_y       11613
# dtype: int64

# %%
sns.heatmap(x.isnull(),cbar=False,cmap='viridis')

# %%
num_col = ['Price_x', 'Year_x',  'Mileage_x','Price_y','Year_y','Mileage_y']
for col in num_col:
    x[col]=pd.to_numeric(x[col])
    x[col].fillna(x[col].mean(), inplace=True)
x.head()
# Out:
#    Price_x  Year_x  Mileage_x            City_x State_x                Vin  \
# 0   8995.0  2014.0    35725.0           El Paso      TX  19VDE2E53EE000083
# 1  10888.0  2013.0    19606.0  Long Island City      NY  19VDE1F52DE012636
# 2   8995.0  2013.0    48851.0           El Paso      TX  19VDE2E52DE000025
# 3  10999.0  2014.0    39922.0           Windsor      CO  19VDE1F71EE003817
# 4  14799.0  2016.0    22142.0            Lindon      UT  19UDE2F32GA001284
#
#   Make_x       Model_x  Price_y  Year_y  Mileage_y            City_y State_y  \
# 0  Acura    ILX6-Speed   8995.0  2014.0    35725.0           El Paso      TX
# 1  Acura    ILX5-Speed  10888.0  2013.0    19606.0  Long Island City      NY
# 2  Acura    ILX6-Speed   8995.0  2013.0    48851.0           El Paso      TX
# 3  Acura    ILX5-Speed  10999.0  2014.0    39922.0           Windsor      CO
# 4  Acura  ILXAutomatic  14799.0  2016.0    22142.0            Lindon      UT
#
#   Make_y       Model_y
# 0  Acura    ILX6-Speed
# ...

# %%
num_col = ['City_x', 'State_x','Make_x','Model_x','City_y','State_y','Make_y','Model_y']
for col in num_col:
    x[col]=x.to_numeric(x[col])
    x[col].fillna(x[col].mean(), inplace=True)
x.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-354dea707a28> in <module>()
#       1 num_col = ['City_x', 'State_x','Make_x','Model_x','City_y','State_y','Make_y','Model_y']
#       2 for col in num_col:
# ----> 3     x[col]=x.to_numeric(x[col])
#       4     x[col].fillna(x[col].mean(), inplace=True)
#       5 x.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_numeric'

# %%
plt.figure(figsize=(10,10))
sns.heatmap(x.corr(),cbar=True,annot=True,cmap='Blues')

# %%
x.drop(['Vin'], axis=1)
# Out:
#              Price_x       Year_x     Mileage_x            City_x State_x  \
# 0         8995.00000  2014.000000  35725.000000           El Paso      TX
# 1        10888.00000  2013.000000  19606.000000  Long Island City      NY
# 2         8995.00000  2013.000000  48851.000000           El Paso      TX
# 3        10999.00000  2014.000000  39922.000000           Windsor      CO
# 4        14799.00000  2016.000000  22142.000000            Lindon      UT
# ...              ...          ...           ...               ...     ...
# 1227905  21464.10021  2013.289145  52507.794921               NaN     NaN
# 1227906  21464.10021  2013.289145  52507.794921               NaN     NaN
# 1227907  21464.10021  2013.289145  52507.794921               NaN     NaN
# 1227908  21464.10021  2013.289145  52507.794921               NaN     NaN
# 1227909  21464.10021  2013.289145  52507.794921               NaN     NaN
#
#         Make_x       Model_x  Price_y  Year_y  Mileage_y            City_y  \
# ...

# %%
sns.histplot(x.Price_y,bins=10)

# %%
x.figure(figsize=(13,4))
sns.countplot(df.Platform.dropna(),order = df.Platform.value_counts().index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-c6cf9e0619a3> in <module>()
# ----> 1 x.figure(figsize=(13,4))
#       2 sns.countplot(df.Platform.dropna(),order = df.Platform.value_counts().index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'figure'
